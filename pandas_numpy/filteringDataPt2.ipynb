# %%
import pandas as pd
import numpy as np

# %%
df_laptops = pd.read_csv('FilteringData/laptop_price.csv', encoding='unicode_escape')
df_laptops.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
#using np.select for more than 2 choices
#creating an array based on multiple price tiers (>2 choices)
#creating 'conditions' and 'values' variables
price_conditions = [
    df_laptops['Price_euros'] < 1200,
    (df_laptops['Price_euros'] >= 1200) & (df_laptops['Price_euros'] <= 1900),
    df_laptops['Price_euros'] > 1900
]

prices_values = ['Cheap','Mid Tier', 'Expensive']

#creating a new column to match the values to the price connditions with np.select()
df_laptops['Price_tier'] = np.select(price_conditions,prices_values,default='Unknown')

# %%
df_laptops.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
#isin():Single filtering
#Select Apple or HP Laptops
df_laptops['Company'].isin(['Apple','HP'])
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301     True
# 1302    False
# Name: Company, Length: 1303, dtype: bool

# %%
#filter dataframe
df_laptops[df_laptops['Company'].isin(['Apple','HP'])]
# Out:
#       laptop_ID Company                              Product   TypeName  \
# 0             1   Apple                          MacBook Pro  Ultrabook
# 1             2   Apple                          Macbook Air  Ultrabook
# 2             3      HP                               250 G6   Notebook
# 3             4   Apple                          MacBook Pro  Ultrabook
# 4             5   Apple                          MacBook Pro  Ultrabook
# ...         ...     ...                                  ...        ...
# 1282       1300      HP                     Stream 11-Y000na    Netbook
# 1287       1305      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
# 1294       1312      HP                  Pavilion 15-AW003nv   Notebook
# 1296       1314      HP                     Stream 11-Y000na    Netbook
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
#
#       Inches                    ScreenResolution  \
# 0       13.3  IPS Panel Retina Display 2560x1600
# ...

# %%
#isin(): Multiple filtering
#find notebooks or ultrabooks from Apple or HP
filter1 = df_laptops['TypeName'].isin(['Notebook','Ultrabook'])
filter2 = df_laptops['Company'].isin(['HP','Apple'])
df_laptops[filter1 & filter2]
# Out:
#       laptop_ID Company                              Product   TypeName  \
# 0             1   Apple                          MacBook Pro  Ultrabook
# 1             2   Apple                          Macbook Air  Ultrabook
# 2             3      HP                               250 G6   Notebook
# 3             4   Apple                          MacBook Pro  Ultrabook
# 4             5   Apple                          MacBook Pro  Ultrabook
# ...         ...     ...                                  ...        ...
# 1273       1291      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
# 1280       1298      HP                  Pavilion 15-AW003nv   Notebook
# 1287       1305      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
# 1294       1312      HP                  Pavilion 15-AW003nv   Notebook
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
#
#       Inches                    ScreenResolution                         Cpu  \
# ...

# %%
df_laptops[filter1 & filter2].value_counts('Company')
# Out:
# Company
# HP       220
# Apple     21
# Name: count, dtype: int64

# %%
#Find duplicates in 1 column/series (laptop_ID)
df_laptops[df_laptops.duplicated('laptop_ID')]
# Out:
# Empty DataFrame
# Columns: [laptop_ID, Company, Product, TypeName, Inches, ScreenResolution, Cpu, Ram, Memory, Gpu, OpSys, Weight, Price_euros, Price_tier]
# Index: []

# %%
#Duplicates in 2 or more columns
df_laptops[df_laptops.duplicated(['Product','TypeName','Inches'])]
# Out:
#       laptop_ID Company                              Product  \
# 4             5   Apple                          MacBook Pro
# 6             7   Apple                          MacBook Pro
# 7             8   Apple                          Macbook Air
# 10           11      HP                               250 G6
# 11           12      HP                               250 G6
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 4              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
#Sort dataframe ascending by company and price
#Cheapest first and most expensive last
df_laptops = df_laptops.sort_values(['Company','Price_euros']) 
df_laptops.head()
# Out:
#       laptop_ID Company                           Product  TypeName  Inches  \
# 1215       1233    Acer  C740-C9QX (3205U/2GB/32GB/Chrome   Netbook    11.6
# 290         295    Acer              Chromebook C910-C2ST  Notebook    15.6
# 1102       1117    Acer                     Chromebook 15  Notebook    15.6
# 695         703    Acer                 TravelMate B117-M   Netbook    11.6
# 1198       1216    Acer                          Aspire 3  Notebook    15.6
#
#      ScreenResolution                                   Cpu  Ram  \
# 1215         1366x768  Intel Celeron Dual Core 3205U 1.5GHz  2GB
# 290          1366x768  Intel Celeron Dual Core 3205U 1.5GHz  2GB
# 1102         1366x768  Intel Celeron Dual Core 3205U 1.5GHz  4GB
# 695          1366x768  Intel Celeron Dual Core N3050 1.6GHz  4GB
# 1198         1366x768    Intel Celeron Dual Core N3350 2GHz  4GB
#
#                   Memory                    Gpu       OpSys  Weight  \
# ...

# %%
df_laptops
# Out:
#       laptop_ID Company                           Product   TypeName  Inches  \
# 1215       1233    Acer  C740-C9QX (3205U/2GB/32GB/Chrome    Netbook    11.6
# 290         295    Acer              Chromebook C910-C2ST   Notebook    15.6
# 1102       1117    Acer                     Chromebook 15   Notebook    15.6
# 695         703    Acer                 TravelMate B117-M    Netbook    11.6
# 1198       1216    Acer                          Aspire 3   Notebook    15.6
# ...         ...     ...                               ...        ...     ...
# 191         195    Vero     K147 (N3350/4GB/32GB/FHD/W10)   Notebook    14.0
# 877         888  Xiaomi                       Mi Notebook  Ultrabook    13.3
# 192         196  Xiaomi                       Mi Notebook  Ultrabook    13.3
# 184         188  Xiaomi                       Mi Notebook   Notebook    15.6
# 514         521  Xiaomi                       Mi Notebook   Notebook    15.6
#
# ...

# %%
#Checking for all values in "Company" column
df_laptops['Company'].value_counts()
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Mediacom       7
# Razer          7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Chuwi          3
# Fujitsu        3
# LG             3
# Google         3
# Huawei         2
# Name: count, dtype: int64

# %%
#Duplicated values in "Company" columns (default -> keep='first')
duplicated_first = df_laptops.duplicated('Company',keep='first')
duplicated_first
# Out:
# 1215    False
# 290      True
# 1102     True
# 695      True
# 1198     True
#         ...
# 191      True
# 877     False
# 192      True
# 184      True
# 514      True
# Length: 1303, dtype: bool

# %%
#Show dataframe with duplicated values in "Company" column
df_laptops[duplicated_first] 
#Keep first (Cheapest laptop per company)
#Show DF with non duplicated values in "Company" column
# ~ is the not operator
df_laptops[~duplicated_first][['Company','Price_euros','Inches']]
# Out:
#         Company  Price_euros  Inches
# 1215       Acer       174.00    11.6
# 1         Apple       898.94    13.3
# 20         Asus       191.90    11.6
# 30        Chuwi       244.99    15.6
# 340        Dell       274.90    15.6
# 983     Fujitsu       649.00    15.6
# 472      Google      1275.00    12.3
# 1268         HP       209.00    11.6
# 170      Huawei      1349.00    13.0
# 909          LG      1899.00    14.0
# 1272     Lenovo       229.00    14.0
# 1169        MSI       839.00    15.6
# 626    Mediacom       239.00    14.0
# 457   Microsoft       989.00    13.5
# 1117      Razer      1029.00    12.5
# 430     Samsung       269.00    11.6
# 159     Toshiba       447.00    15.6
# 1120       Vero       196.00    13.3
# 877      Xiaomi       935.00    13.3

# %%
#Check all value companies
df_laptops[~duplicated_first].value_counts('Company')
# Out:
# Company
# Acer         1
# Apple        1
# Asus         1
# Chuwi        1
# Dell         1
# Fujitsu      1
# Google       1
# HP           1
# Huawei       1
# LG           1
# Lenovo       1
# MSI          1
# Mediacom     1
# Microsoft    1
# Razer        1
# Samsung      1
# Toshiba      1
# Vero         1
# Xiaomi       1
# Name: count, dtype: int64

# %%
#now the same with most expensive laptop
df_laptops = df_laptops.sort_values(
    by=['Company', 'Price_euros'], 
    ascending=[True, False]
)
df_laptops
duplicated_most_expensive = df_laptops.duplicated('Company',keep='first')
df_laptops[~duplicated_most_expensive][['Company','Price_euros']]
# Out:
#         Company  Price_euros
# 1189       Acer      2599.00
# 17        Apple      2858.00
# 1066       Asus      3975.00
# 421       Chuwi       449.00
# 723        Dell      3659.40
# 623     Fujitsu       799.00
# 437      Google      2199.00
# 749          HP      4389.00
# 214      Huawei      1499.00
# 678          LG      2299.00
# 610      Lenovo      4899.00
# 177         MSI      2799.00
# 580    Mediacom       389.00
# 449   Microsoft      2589.00
# 196       Razer      6099.00
# 874     Samsung      1849.00
# 491     Toshiba      2799.00
# 191        Vero       260.00
# 514      Xiaomi      1399.95

# %%
(df_laptops['Company'] == 'Vero').sum()
# Out:
# np.int64(4)

# %%
#drop duplicates in 2 or more columns
df_laptops.drop_duplicates(['Company']).value_counts(['Company'])
# Out:
# Company
# Acer         1
# Apple        1
# Asus         1
# Chuwi        1
# Dell         1
# Fujitsu      1
# Google       1
# HP           1
# Huawei       1
# LG           1
# Lenovo       1
# MSI          1
# Mediacom     1
# Microsoft    1
# Razer        1
# Samsung      1
# Toshiba      1
# Vero         1
# Xiaomi       1
# Name: count, dtype: int64

# %%
#sort dataframe ascending by company and price
#cheapest first and most expensive last
df_laptops = df_laptops.sort_values(['Company','Price_euros'],ascending=True)
df_laptops.head()
# Out:
#       laptop_ID Company                           Product  TypeName  Inches  \
# 1215       1233    Acer  C740-C9QX (3205U/2GB/32GB/Chrome   Netbook    11.6
# 290         295    Acer              Chromebook C910-C2ST  Notebook    15.6
# 1102       1117    Acer                     Chromebook 15  Notebook    15.6
# 695         703    Acer                 TravelMate B117-M   Netbook    11.6
# 1198       1216    Acer                          Aspire 3  Notebook    15.6
#
#      ScreenResolution                                   Cpu  Ram  \
# 1215         1366x768  Intel Celeron Dual Core 3205U 1.5GHz  2GB
# 290          1366x768  Intel Celeron Dual Core 3205U 1.5GHz  2GB
# 1102         1366x768  Intel Celeron Dual Core 3205U 1.5GHz  4GB
# 695          1366x768  Intel Celeron Dual Core N3050 1.6GHz  4GB
# 1198         1366x768    Intel Celeron Dual Core N3350 2GHz  4GB
#
#                   Memory                    Gpu       OpSys  Weight  \
# ...

# %%
#Cheapest: keep='first'
df_laptops.drop_duplicates(['Company'], keep='first')[['Company','Price_euros']]
# Out:
#         Company  Price_euros
# 1215       Acer       174.00
# 1         Apple       898.94
# 20         Asus       191.90
# 30        Chuwi       244.99
# 340        Dell       274.90
# 983     Fujitsu       649.00
# 472      Google      1275.00
# 1268         HP       209.00
# 170      Huawei      1349.00
# 909          LG      1899.00
# 1272     Lenovo       229.00
# 1169        MSI       839.00
# 626    Mediacom       239.00
# 457   Microsoft       989.00
# 1117      Razer      1029.00
# 430     Samsung       269.00
# 159     Toshiba       447.00
# 1120       Vero       196.00
# 877      Xiaomi       935.00

# %%
#most expensive keep='last'
df_laptops.drop_duplicates(['Company'],keep='last')[['Company','Price_euros']]
# Out:
#       Company  Price_euros
# 0        Acer      2599.00
# 1       Apple      2858.00
# 2        Asus      3975.00
# 3       Chuwi       449.00
# 4        Dell      3659.40
# 5     Fujitsu       799.00
# 6      Google      2199.00
# 7          HP      4389.00
# 8      Huawei      1499.00
# 9          LG      2299.00
# 10     Lenovo      4899.00
# 11        MSI      2799.00
# 12   Mediacom       389.00
# 13  Microsoft      2589.00
# 14      Razer      6099.00
# 15    Samsung      1849.00
# 16    Toshiba      2799.00
# 17       Vero       260.00
# 18     Xiaomi      1399.95

# %%
#arguments
#inplace: drop duplicates in place or return to a copy
#ignore_index=True : the resulting axis will be labelled 0,1, ...
df_laptops.drop_duplicates(['Company'],keep='last',inplace=True,ignore_index=True)
df_laptops[['Company','Price_euros']]
# Out:
#       Company  Price_euros
# 0        Acer      2599.00
# 1       Apple      2858.00
# 2        Asus      3975.00
# 3       Chuwi       449.00
# 4        Dell      3659.40
# 5     Fujitsu       799.00
# 6      Google      2199.00
# 7          HP      4389.00
# 8      Huawei      1499.00
# 9          LG      2299.00
# 10     Lenovo      4899.00
# 11        MSI      2799.00
# 12   Mediacom       389.00
# 13  Microsoft      2589.00
# 14      Razer      6099.00
# 15    Samsung      1849.00
# 16    Toshiba      2799.00
# 17       Vero       260.00
# 18     Xiaomi      1399.95

# %%
#sort dataframe ascending by company and inches
#smallest first and biggest last
df_laptops_new = pd.read_csv('FilteringData/laptop_price.csv', encoding='unicode_escape')
df_laptops_new = df_laptops_new.sort_values(by=['Company', 'Inches'])
df_laptops_new
# Out:
#       laptop_ID Company                               Product  \
# 319         324    Acer                          TravelMate B
# 461         468    Acer                          TravelMate B
# 560         567    Acer                         Spin SP111-31
# 619         626    Acer  CB5-132T-C9KK (N3160/4GB/32GB/Chrome
# 695         703    Acer                     TravelMate B117-M
# ...         ...     ...                                   ...
# 1041       1055    Vero          V142 (X5-Z8350/2GB/32GB/W10)
# 192         196  Xiaomi                           Mi Notebook
# 877         888  Xiaomi                           Mi Notebook
# 184         188  Xiaomi                           Mi Notebook
# 514         521  Xiaomi                           Mi Notebook
#
#                 TypeName  Inches                           ScreenResolution  \
# 319             Notebook    11.6                                   1366x768
# ...

# %%
#smallest: keep='first'
df_laptops_new.drop_duplicates(['Company'],keep='first')[['Company','Inches']]
# Out:
#         Company  Inches
# 319        Acer    11.6
# 1234      Apple    11.6
# 20         Asus    11.6
# 421       Chuwi    12.3
# 455        Dell    11.6
# 567     Fujitsu    15.6
# 437      Google    12.3
# 677          HP    11.6
# 170      Huawei    13.0
# 909          LG    14.0
# 50       Lenovo    10.1
# 785         MSI    14.0
# 429    Mediacom    11.6
# 70    Microsoft    13.5
# 816       Razer    12.5
# 430     Samsung    11.6
# 963     Toshiba    12.5
# 1120       Vero    13.3
# 192      Xiaomi    13.3

# %%
#largest: keep='last'
df_laptops_new.drop_duplicates(['Company'],keep='last')[['Company','Inches']]
# Out:
#         Company  Inches
# 1216       Acer    17.3
# 17        Apple    15.4
# 1256       Asus    17.3
# 483       Chuwi    15.6
# 1243       Dell    17.3
# 983     Fujitsu    15.6
# 762      Google    12.3
# 1136         HP    17.3
# 214      Huawei    13.0
# 905          LG    15.6
# 1217     Lenovo    17.3
# 177         MSI    18.4
# 718    Mediacom    14.0
# 670   Microsoft    13.5
# 830       Razer    17.3
# 593     Samsung    15.6
# 1042    Toshiba    15.6
# 1041       Vero    14.0
# 514      Xiaomi    15.6

# %%
#unique values
#get unique elements in "Company" column
df_laptops = df_laptops_new
df_laptops['Company'].unique()
# Out:
# array(['Acer', 'Apple', 'Asus', 'Chuwi', 'Dell', 'Fujitsu', 'Google',
#        'HP', 'Huawei', 'LG', 'Lenovo', 'MSI', 'Mediacom', 'Microsoft',
#        'Razer', 'Samsung', 'Toshiba', 'Vero', 'Xiaomi'], dtype=object)

# %%
#getting unique element in the inches column
unique_inches = df_laptops['Inches'].unique()
unique_inches
# Out:
# array([11.6, 13.3, 14. , 15.6, 17.3, 12. , 15.4, 12.5, 14.1, 12.3, 15. ,
#        17. , 13. , 10.1, 11.3, 13.9, 18.4, 13.5])

# %%
#getting the length of the unique elements
len(unique_inches)
# Out:
# 18

# %%
#nunique(): number of unique values
#get the number of unique elements in the 'Company' column 
df_laptops['Company'].nunique()
# Out:
# 19

# %%
#get the number of unique elements in the 'Inches' column 
df_laptops['Inches'].nunique()
# Out:
# 18
